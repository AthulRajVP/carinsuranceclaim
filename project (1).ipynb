# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r'D:\vs\ml\car_insurance_claim_new.csv')
df
# Out:
#       Claim_ID  Age  Gender Policy_Type Vehicle_Type Accident_Type  \
# 0        52737   62    Male       Basic    Hatchback    Total Loss
# 1        54780   18    Male     Premium        Truck         Minor
# 2        52366   45    Male       Basic        Truck    Total Loss
# 3        55607   30  Female     Premium          SUV         Major
# 4        53330   61  Female     Premium        Truck    Total Loss
# ...        ...  ...     ...         ...          ...           ...
# 7692     60996   33    Male     Premium        Sedan         Minor
# 7693     60997   69    Male     Premium          SUV         Major
# 7694     60998   57    Male     Premium        Truck    Total Loss
# 7695     60999   33  Female     Premium    Hatchback         Major
# 7696     61000   70    Male        Gold        Truck         Minor
#
#       Annual_Premium  Claim_Amount Police_Report Witness_Present  Past_Claims  \
# 0            18659.0        541486           Yes              No            2
# ...

# %%
df.head()
# Out:
#    Claim_ID  Age  Gender Policy_Type Vehicle_Type Accident_Type  \
# 0     52737   62    Male       Basic    Hatchback    Total Loss
# 1     54780   18    Male     Premium        Truck         Minor
# 2     52366   45    Male       Basic        Truck    Total Loss
# 3     55607   30  Female     Premium          SUV         Major
# 4     53330   61  Female     Premium        Truck    Total Loss
#
#    Annual_Premium  Claim_Amount Police_Report Witness_Present  Past_Claims  \
# 0         18659.0        541486           Yes              No            2
# 1         77745.0        160786            No              No            5
# 2         78989.0        573160           Yes              No            5
# 3         62574.0        420964           Yes              No            2
# 4         33564.0        521902            No              No            2
#
#    Days_To_Claim Incident_Location  Claim_Status
# 0              4             Urban             0
# ...

# %%
df.tail()
# Out:
#       Claim_ID  Age  Gender Policy_Type Vehicle_Type Accident_Type  \
# 7692     60996   33    Male     Premium        Sedan         Minor
# 7693     60997   69    Male     Premium          SUV         Major
# 7694     60998   57    Male     Premium        Truck    Total Loss
# 7695     60999   33  Female     Premium    Hatchback         Major
# 7696     61000   70    Male        Gold        Truck         Minor
#
#       Annual_Premium  Claim_Amount Police_Report Witness_Present  Past_Claims  \
# 7692         60388.0         83345           Yes             Yes            2
# 7693         77933.0        156938            No             Yes            4
# 7694         43568.0        475856            No              No            4
# 7695         26797.0        515945            No             Yes            4
# 7696         17192.0        275345            No             Yes            0
#
#       Days_To_Claim Incident_Location  Claim_Status
# ...

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(y=df['Claim_Amount'])
# Out:
# <Axes: ylabel='Claim_Amount'>

# %%
q1 = np.percentile(df['Claim_Amount'].dropna(), 25)
q3 = np.percentile(df['Claim_Amount'].dropna(), 75)
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr
df.loc[(df['Claim_Amount'] < lower) | (df['Claim_Amount'] > upper), 'Claim_Amount'] = np.nan
df.dropna(subset=['Claim_Amount'], inplace=True)
df
# Out:
#       Claim_ID  Age  Gender Policy_Type Vehicle_Type Accident_Type  \
# 0        52737   62    Male       Basic    Hatchback    Total Loss
# 1        54780   18    Male     Premium        Truck         Minor
# 2        52366   45    Male       Basic        Truck    Total Loss
# 3        55607   30  Female     Premium          SUV         Major
# 4        53330   61  Female     Premium        Truck    Total Loss
# ...        ...  ...     ...         ...          ...           ...
# 7692     60996   33    Male     Premium        Sedan         Minor
# 7693     60997   69    Male     Premium          SUV         Major
# 7694     60998   57    Male     Premium        Truck    Total Loss
# 7695     60999   33  Female     Premium    Hatchback         Major
# 7696     61000   70    Male        Gold        Truck         Minor
#
#       Annual_Premium  Claim_Amount Police_Report Witness_Present  Past_Claims  \
# 0            18659.0      541486.0           Yes              No            2
# ...

# %%
sns.boxplot(y=df['Claim_Amount'])
# Out:
# <Axes: ylabel='Claim_Amount'>

# %%
df.isna().sum()
# Out:
# Claim_ID             0
# Age                  0
# Gender               0
# Policy_Type          0
# Vehicle_Type         0
# Accident_Type        0
# Annual_Premium       3
# Claim_Amount         0
# Police_Report        3
# Witness_Present      6
# Past_Claims          0
# Days_To_Claim        0
# Incident_Location    0
# Claim_Status         0
# dtype: int64

# %%
d1=df['Annual_Premium'].value_counts()
d1
# Out:
# Annual_Premium
# 52464.0    370
# 31734.0      6
# 54855.0      6
# 37203.0      6
# 72804.0      6
#           ...
# 20755.0      1
# 50608.0      1
# 63652.0      1
# 71965.0      1
# 79446.0      1
# Name: count, Length: 4317, dtype: int64

# %%
plt.bar(df['Annual_Premium'].index,df['Annual_Premium'].values)
plt.show()

# %%
d2=df['Claim_Amount'].value_counts()
d2
# Out:
# Claim_Amount
# 307567.0    409
# 482051.0      7
# 517511.0      6
# 541277.0      5
# 211323.0      5
#            ...
# 165071.0      1
# 463527.0      1
# 402675.0      1
# 563777.0      1
# 257368.0      1
# Name: count, Length: 4392, dtype: int64

# %%
plt.bar(df['Claim_Amount'].index,df['Claim_Amount'].values)
# Out:
# <BarContainer object of 7631 artists>

# %%
d3=df['Police_Report'].value_counts()
d3
# Out:
# Police_Report
# Yes    4089
# No     3539
# Name: count, dtype: int64

# %%
plt.bar(d3.index,d3.values)
# Out:
# <BarContainer object of 2 artists>

# %%
d=df['Witness_Present'].value_counts()
d
# Out:
# Witness_Present
# Yes    4036
# No     3589
# Name: count, dtype: int64

# %%
plt.bar(d.index,d.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df['Annual_Premium']=df['Annual_Premium'].fillna(df['Annual_Premium'].median())
df['Claim_Amount']=df['Claim_Amount'].fillna(df['Claim_Amount'].median())
df['Police_Report']=df['Police_Report'].fillna(df['Police_Report'].mode()[0])
df['Witness_Present']=df['Witness_Present'].fillna(df['Witness_Present'].mode()[0])

# %%
df.isna().sum()
# Out:
# Claim_ID             0
# Age                  0
# Gender               0
# Policy_Type          0
# Vehicle_Type         0
# Accident_Type        0
# Annual_Premium       0
# Claim_Amount         0
# Police_Report        0
# Witness_Present      0
# Past_Claims          0
# Days_To_Claim        0
# Incident_Location    0
# Claim_Status         0
# dtype: int64

# %%
df.dtypes
# Out:
# Claim_ID               int64
# Age                    int64
# Gender                object
# Policy_Type           object
# Vehicle_Type          object
# Accident_Type         object
# Annual_Premium       float64
# Claim_Amount         float64
# Police_Report         object
# Witness_Present       object
# Past_Claims            int64
# Days_To_Claim          int64
# Incident_Location     object
# Claim_Status           int64
# dtype: object

# %%
d=df['Gender'].value_counts()
d
# Out:
# Gender
# Male      3894
# Female    3737
# Name: count, dtype: int64

# %%
d2=df['Policy_Type'].value_counts()
d2
# Out:
# Policy_Type
# Premium    2623
# Gold       2510
# Basic      2498
# Name: count, dtype: int64

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# SUV          1977
# Hatchback    1905
# Sedan        1893
# Truck        1856
# Name: count, dtype: int64

# %%
df['Accident_Type'].value_counts()
# Out:
# Accident_Type
# Minor         2854
# Total Loss    2408
# Major         2369
# Name: count, dtype: int64

# %%
df['Police_Report'].value_counts()
# Out:
# Police_Report
# Yes    4092
# No     3539
# Name: count, dtype: int64

# %%
df['Witness_Present'].value_counts()
# Out:
# Witness_Present
# Yes    4042
# No     3589
# Name: count, dtype: int64

# %%
df['Incident_Location'].value_counts()
# Out:
# Incident_Location
# Urban    3856
# Rural    3775
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=['Gender','Policy_Type','Vehicle_Type','Accident_Type','Police_Report','Witness_Present','Incident_Location'],drop_first=True,dtype=int)

# %%
df
# Out:
#       Claim_ID  Age  Annual_Premium  Claim_Amount  Past_Claims  Days_To_Claim  \
# 0        52737   62         18659.0      541486.0            2              4
# 1        54780   18         77745.0      160786.0            5             40
# 2        52366   45         78989.0      573160.0            5             21
# 3        55607   30         62574.0      420964.0            2             35
# 4        53330   61         33564.0      521902.0            2             13
# ...        ...  ...             ...           ...          ...            ...
# 7692     60996   33         60388.0       83345.0            2              9
# 7693     60997   69         77933.0      156938.0            4             21
# 7694     60998   57         43568.0      475856.0            4             38
# 7695     60999   33         26797.0      515945.0            4             13
# 7696     61000   70         17192.0      275345.0            0             22
#
# ...

# %%
x=df.drop(['Claim_ID','Claim_Status'],axis=1)

# %%
y=df['Claim_Status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (5341, 16)

# %%
x_test.shape
# Out:
# (2290, 16)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit_transform(x_train)
scaler.transform(x_test)
# Out:
# array([[ 1.31345931, -0.68023949, -0.03228005, ..., -1.0748801 ,
#          0.93419532, -1.00206166],
#        [-0.01984605,  0.80059424,  0.49625172, ..., -1.0748801 ,
#          0.93419532,  0.99794258],
#        [ 1.07104015, -0.69095464, -1.10591176, ...,  0.93033632,
#         -1.07043996, -1.00206166],
#        ...,
#        [-1.17133705,  1.61159133, -1.20713366, ..., -1.0748801 ,
#          0.93419532, -1.00206166],
#        [-0.26226521, -0.73730931, -0.42210835, ...,  0.93033632,
#         -1.07043996,  0.99794258],
#        [-1.29254663, -1.66053595,  0.72633446, ...,  0.93033632,
#          0.93419532, -1.00206166]], shape=(2290, 16))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
model=KNeighborsClassifier(n_neighbors=42)
model2=DecisionTreeClassifier(criterion='entropy',random_state=42)
model3=GaussianNB()
model4=RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
lst=[model,model2,model3,model4]
for i in lst:
  print('model name is',i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print(y_pred)
  print('accuracy score:',accuracy_score(y_test,y_pred))
  print('confusion matrics:',confusion_matrix(y_test,y_pred))
  print('classification report',classification_report(y_test,y_pred))
  print('******************************************************')
# Out:
# model name is KNeighborsClassifier(n_neighbors=42)
# [0 0 0 ... 1 0 0]
# accuracy score: 0.6187772925764192
# confusion matrics: [[1197  201]
#  [ 672  220]]
# classification report               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73      1398
#            1       0.52      0.25      0.34       892
#
#     accuracy                           0.62      2290
#    macro avg       0.58      0.55      0.53      2290
# weighted avg       0.59      0.62      0.58      2290
#
# ******************************************************
# model name is DecisionTreeClassifier(criterion='entropy', random_state=42)
# [0 0 1 ... 0 1 0]
# accuracy score: 0.8074235807860262
# confusion matrics: [[1170  228]
#  [ 213  679]]
# classification report               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      1398
#            1       0.75      0.76      0.75       892
#
# ...

# %%
from sklearn.model_selection import GridSearchCV
model=RandomForestClassifier()
param_grid={
    'n_estimators':[100],
    'criterion':['gini','entropy','log_loss'],
    'max_depth':[5,10,15],
    'min_samples_leaf': [1,2,4],
    'min_samples_split': [2,5,10]
}
toning=GridSearchCV(model,param_grid,cv=10)
toning.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100]})

# %%
print(toning.best_params_)
# Out:
# {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
newmodel=RandomForestClassifier(criterion='gini',max_depth=15,min_samples_leaf=1,min_samples_split=2,n_estimators= 100)

# %%
newmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=15)

# %%
ny_pred=newmodel.predict(x_test)

# %%
ac=accuracy_score(y_test,ny_pred)
ac
# Out:
# 0.8502183406113537

# %%
cm=confusion_matrix(y_test,ny_pred)
cm
# Out:
# array([[1353,   45],
#        [ 298,  594]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1398
#            1       0.93      0.68      0.79       892
#
#     accuracy                           0.86      2290
#    macro avg       0.88      0.82      0.84      2290
# weighted avg       0.87      0.86      0.85      2290

# %%
import joblib
joblib.dump(newmodel,'carinsuranceclaim.joblib')
# Out:
# ['carinsuranceclaim.joblib']
